# %% [markdown]
# <a href="https://colab.research.google.com/github/akshay777-aar/Daily-Task-and-Case-Studies-/blob/main/Case_Study_on_Data_Acquisition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task: Acquiring and Analyzing a Free Dataset from the Internet

# %% [markdown]
# # Objective
# Your task is to find a free dataset from the internet that can be accessed using pandas, and then
# analyze the data by answering specific questions.

# %% [markdown]
# # Instructions

# %% [markdown]
# # 1. Find a Dataset:
#
# Search for a free, publicly accessible dataset on the internet. Good sources
# include:
# ■ Kaggle Datasets
# ■ UCI Machine Learning Repository
# ■ data.gov
# ■ Google Dataset Search

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Load the Dataset:
#
# Ensure the dataset can be loaded using pandas. It should be in one of the
# following formats: CSV, Excel, JSON, or directly accessible via a URL.

# %%
data = pd.read_csv('/content/drive/MyDrive/Documents/matches.csv')

# %% [markdown]
# # 3. Perform Initial Exploration:
#
# ○ Load the dataset into a pandas DataFrame.
#
# ○ Display the first few rows of the DataFrame to understand its structure.
#
# ○ Print the summary statistics of the dataset.

# %%
data.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %%
data.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %% [markdown]
# # 4. Answer the Following Questions:

# %% [markdown]
# Q1: What is the size of the dataset? (Number of rows and columns)

# %%
data.size
# Out:
# 21900

# %%
data.shape
# Out:
# (1095, 20)

# %% [markdown]
# Q2: What are the data types of each column?

# %%
data.dtypes
# Out:
# id                   int64
# season              object
# city                object
# date                object
# match_type          object
# player_of_match     object
# venue               object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# target_runs        float64
# target_overs       float64
# super_over          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %% [markdown]
# Q3: Are there any missing values in the dataset? If so, which columns have
# missing values and how many?

# %%
data.replace('-', np.NaN, inplace=True)
data.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
data.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %% [markdown]
# Q4: What are the unique values in a categorical column of your choice? How
# many unique values are there?

# %%
data.city.unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', nan, 'Rajkot', 'Kanpur', 'Bengaluru', 'Dubai',
#        'Sharjah', 'Navi Mumbai', 'Lucknow', 'Guwahati', 'Mohali'],
#       dtype=object)

# %%
data.city.nunique()
# Out:
# 36

# %% [markdown]
# Q5: For a numerical column of your choice, calculate the mean, median, and
# standard deviation.

# %%
data['target_runs']. mean()
# Out:
# 165.68406593406593

# %%
data['target_runs']. median()
# Out:
# 166.0

# %%
data['target_runs']. std()
# Out:
# 33.42704825769165

# %% [markdown]
# Q6: Identify any potential outliers in a numerical column of your choice. Explain
# your approach.

# %%
plt.figure(figsize=(2,10))
sns.boxplot(data['target_runs'])
plt.show()

# %% [markdown]
# Q7: Find the correlation between numerical columns and discuss any interesting
# relationships.

# %%
data1 = data.select_dtypes(include=['number'])
data1.head()
# Out:
#        id  result_margin  target_runs  target_overs
# 0  335982          140.0        223.0          20.0
# 1  335983           33.0        241.0          20.0
# 2  335984            9.0        130.0          20.0
# 3  335985            5.0        166.0          20.0
# 4  335986            5.0        111.0          20.0

# %%
corr = data1.corr()
corr
# Out:
#                      id  result_margin  target_runs  target_overs
# id             1.000000      -0.006853     0.238859      0.046388
# result_margin -0.006853       1.000000     0.395120      0.030970
# target_runs    0.238859       0.395120     1.000000      0.352361
# target_overs   0.046388       0.030970     0.352361      1.000000

# %% [markdown]
# Q8: Group the data by a categorical column and compute the aggregate statistics
# (e.g., mean, sum) for a numerical column.

# %%
data.groupby('city')['target_runs'].agg(['mean','median','std'])
# Out:
#                       mean  median        std
# city
# Abu Dhabi       159.891892   163.0  33.289791
# Ahmedabad       171.333333   171.0  31.303126
# Bangalore       167.343750   166.5  38.175958
# Bengaluru       185.689655   183.0  37.173439
# Bloemfontein    136.000000   136.0  21.213203
# Cape Town       133.142857   140.0  43.529410
# Centurion       155.916667   159.5  24.996212
# Chandigarh      168.655738   173.0  31.029494
# Chennai         164.894118   161.0  30.645447
# Cuttack         168.714286   171.0  34.543279
# Delhi           169.606742   169.0  37.393977
# Dharamsala      184.769231   184.0  33.369532
# Dubai           157.230769   165.0  21.947490
# Durban          147.000000   146.0  36.128738
# East London     148.333333   149.0  31.005376
# Guwahati        181.000000   198.0  31.192948
# Hyderabad       162.376623   160.0  36.105488
# Indore          161.333333   164.0  48.163783
# Jaipur          161.052632   161.0  28.260536
# Johannesburg    145.000000   145.5  13.564660
# Kanpur          162.250000   164.0  29.970819
# Kimberley       159.000000   167.0  15.620499
# Kochi           148.400000   157.0  14.741099
# Kolkata         164.430108   168.0  37.416689
# Lucknow         169.538462   168.0  32.589915
# Mohali          168.400000   175.0  21.927152
# Mumbai          170.381503   173.0  31.866256
# Nagpur          150.333333   152.0  10.598742
# Navi Mumbai     169.222222   160.0  23.863035
# Port Elizabeth  160.000000   154.0  17.281975
# Pune            163.372549   165.0  28.044936
# Raipur          147.333333   149.0  18.162232
# Rajkot          169.900000   168.0  22.830048
# Ranchi          150.000000   149.0  22.788886
# Sharjah         137.900000   135.5  23.038374
# Visakhapatnam   160.133333   163.0  48.704454

# %% [markdown]
# Q9:: Based on your analysis, provide a brief summary of any insights or patterns
# you discovered in the dataset.

# %%
plt.scatter(data['target_runs'], data['target_overs'])
plt.xlabel('Target Runs')
plt.ylabel('Target Wickets')
plt.title('Target Runs vs Target Overs')
plt.show()
